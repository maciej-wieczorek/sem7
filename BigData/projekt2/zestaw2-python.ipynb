# %% [markdown]
# # Projekt Apache Spark

# %% [markdown]
# # Wprowadzenie
#
# Wykorzystując ten notatnik jako szablon zrealizuj projekt Apache Spark zgodnie z przydzielonym zestawem.
#
# Kilka uwag:
#
# * Nie modyfikuj ani nie usuwaj paragrafów *markdown* w tym notatniku, chyba że wynika to jednoznacznie z instrukcji.
# * Istniejące paragrafy zawierające *kod* uzupełnij w razie potrzeby zgodnie z instrukcjami
#     - nie usuwaj ich
#     - nie usuwaj zawartych w nich instrukcji oraz kodu
#     - nie modyfikuj ich, jeśli instrukcje jawnie tego nie nakazują
# * Możesz dodawać nowe paragrafy zarówno zawierające kod jak i komentarze dotyczące tego kodu (markdown)

# %% [markdown]
# # Treść projektu
#
# Poniżej w paragrafie markdown wstaw tytuł przydzielonego zestawu

# %% [markdown]
# # Zestaw 2 – nyc-taxi
#
# **Uwaga**
#
# - W ramach wzorca nie są spełnione żadne reguły projektu.
# - Brak konsekwencji w wykorzystaniu właściwego API w ramach poszczególnych części
# - Zadanie *misji głównej* polega na zliczeniu słówek.

# %% [markdown]
# # Działania wstępne
#
# Uruchom poniższy paragraf, aby utworzyć obiekty kontekstu Sparka. Jeśli jest taka potrzeba dostosuj te polecenia. Pamiętaj po potrzebnych bibliotekach.

# %%
from pyspark.sql import SparkSession

# Spark session & context
spark = SparkSession.builder.getOrCreate()

sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/01/15 19:55:46 INFO SparkEnv: Registering MapOutputTracker
# 24/01/15 19:55:46 INFO SparkEnv: Registering BlockManagerMaster
# 24/01/15 19:55:46 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 24/01/15 19:55:46 INFO SparkEnv: Registering OutputCommitCoordinator

# %% [markdown]
# W poniższym paragrafie uzupełnij polecenia definiujące poszczególne zmienne.
#
# Pamiętaj abyś:
#
# * w późniejszym kodzie, dla wszystkich cześci projektu, korzystał z tych zdefiniowanych zmiennych. Wykorzystuj je analogicznie jak parametry
# * przed ostateczną rejestracją projektu usunął ich wartości, tak aby nie pozostawiać w notatniku niczego co mogłoby identyfikować Ciebie jako jego autora

# %%
# pełna ścieżka do katalogu w zasobniku zawierającego podkatalogi `datasource1` i `datasource4` 
# z danymi źródłowymi
input_dir = ""

# %% [markdown]
# Nie modyfikuj poniższych paragrafów. Wykonaj je i używaj zdefniowanych poniżej zmiennych jak parametrów Twojego programu.

# %%
# NIE ZMIENIAĆ
# ścieżki dla danych źródłowych 
datasource1_dir = input_dir + "/datasource1"
datasource4_dir = input_dir + "/datasource4"

# nazwy i ścieżki dla wyników dla misji głównej 
# część 1 (Spark Core - RDD) 
rdd_result_dir = "/tmp/output1"

# część 2 (Spark SQL - DataFrame)
df_result_table = "output2"

# część 3 (Pandas API on Spark)
ps_result_file = "/tmp/output3.json"

# %%
# NIE ZMIENIAĆ
import os
def remove_file(file):
    if os.path.exists(file):
        os.remove(file)

remove_file("metric_functions.py")
remove_file("tools_functions.py")

# %%
# NIE ZMIENIAĆ
import requests
r = requests.get("https://jankiewicz.pl/bigdata/metric_functions.py", allow_redirects=True)
open('metric_functions.py', 'wb').write(r.content)
r = requests.get("https://jankiewicz.pl/bigdata/tools_functions.py", allow_redirects=True)
open('tools_functions.py', 'wb').write(r.content)
# Out:
# 3322

# %%
# NIE ZMIENIAĆ
# %run metric_functions.py
# %run tools_functions.py

# %% [markdown]
# Poniższe paragrafy mają na celu usunąć ewentualne pozostałości poprzednich uruchomień tego lub innych notatników

# %%
# NIE ZMIENIAĆ
# usunięcie miejsca docelowego dla część 1 (Spark Core - RDD) 
delete_dir(spark, rdd_result_dir)
# Out:
# Deleted /tmp/output1
# Successfully deleted file in HDFS: /tmp/output1

# %%
# NIE ZMIENIAĆ
# usunięcie miejsca docelowego dla część 2 (Spark SQL - DataFrame) 
drop_table(spark, df_result_table)
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# The table output2 does not exist.
# Error deleting file file:/spark-warehouse/output2: Command '['hadoop', 'fs', '-rm', '-r', 'file:/spark-warehouse/output2']' returned non-zero exit status 1.
# rm: `file:/spark-warehouse/output2': No such file or directory

# %%
# NIE ZMIENIAĆ
# usunięcie miejsca docelowego dla część 3 (Pandas API on Spark) 
remove_file(ps_result_file)

# %%
# NIE ZMIENIAĆ
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://pbd-cluster-m.europe-central2-c.c.big-data-2023-10-mw.internal:38021">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ***Uwaga!***
#
# Uruchom poniższy paragraf i sprawdź czy adres, pod którym dostępny *Apache Spark Application UI* jest poprawny wywołując następny testowy paragraf.
#
# W razie potrzeby określ samodzielnie poprawny adres, pod którym dostępny *Apache Spark Application UI*

# %%
# adres URL, pod którym dostępny Apache Spark Application UI (REST API)
# 
spark_ui_address = extract_host_and_port(spark, "http://localhost:4041")
spark_ui_address
# Out:
# 'http://pbd-cluster-m.europe-central2-c.c.big-data-2023-10-mw.internal:38021'

# %%
# testowy paragraf
test_metrics = get_current_metrics(spark_ui_address)
test_metrics
# Out:
# {'numTasks': 0,
#  'numActiveTasks': 0,
#  'numCompleteTasks': 0,
#  'numFailedTasks': 0,
#  'numKilledTasks': 0,
#  'numCompletedIndices': 0,
#  'executorDeserializeTime': 0,
#  'executorDeserializeCpuTime': 0,
#  'executorRunTime': 0,
#  'executorCpuTime': 0,
#  'resultSize': 0,
#  'jvmGcTime': 0,
#  'resultSerializationTime': 0,
#  'memoryBytesSpilled': 0,
#  'diskBytesSpilled': 0,
#  'peakExecutionMemory': 0,
#  'inputBytes': 0,
#  'inputRecords': 0,
#  'outputBytes': 0,
#  'outputRecords': 0,
#  'shuffleRemoteBlocksFetched': 0,
#  'shuffleLocalBlocksFetched': 0,
#  'shuffleFetchWaitTime': 0,
#  'shuffleRemoteBytesRead': 0,
#  'shuffleRemoteBytesReadToDisk': 0,
#  'shuffleLocalBytesRead': 0,
#  'shuffleReadBytes': 0,
#  'shuffleReadRecords': 0,
#  'shuffleWriteBytes': 0,
#  'shuffleWriteTime': 0,
#  'shuffleWriteRecords': 0}

# %% [markdown]
# # Część 1 - Spark Core (RDD)
#
# ## Misje poboczne
#
# W ponizszych paragrafach wprowadź swoje rozwiązania *misji pobocznych*, o ile **nie** chcesz, aby oceniana była *misja główna*. W przeciwnym przypadku **KONIECZNIE** pozostaw je **puste**.

# %% [markdown]
# ## Misja główna
#
# Poniższy paragraf zapisuje metryki przed uruchomieniem Twojego rozwiązania *misji głównej*.
#
# Nie musisz go uruchamiać podczas implementacji rozwiązania.

# %%
# NIE ZMIENIAĆ
before_rdd_metrics = get_current_metrics(spark_ui_address)

# %% [markdown]
# W poniższych paragrafach wprowadź **rozwiązanie** *misji głównej* oparte na *RDD API*.
#
# Pamiętaj o wydajności Twojego przetwarzania, *RDD API* tego wymaga.
#
# Nie wprowadzaj w poniższych paragrafach żadnego kodu, w przypadku wykorzystania *misji pobocznych*.

# %%
# Wczytanie plików tekstowych
trips_rdd = sc.textFile(datasource1_dir).map(lambda x: x.split(',')).map(lambda x: (x[1][:7], x[1][8:10], int(x[3]), float(x[4]), x[7], x[9], float(x[16])))
MONTH = 0
DAY = 1
PASSENGER_COUNT = 2
TRIP_DISTANCE = 3
PULOCATIONID = 4
PAYMENT_TYPE = 5
TOTAL_AMOUNT = 6

taxi_zones_rdd = sc.textFile(datasource4_dir)
taxi_zones_header = taxi_zones_rdd.first()
taxi_zones_rdd = taxi_zones_rdd.filter(lambda x: x != taxi_zones_header).map(lambda x: x.split(',')).map(lambda x: (x[0], x[1].replace('"', '')))

# %%
trips_filtered_rdd = trips_rdd.filter(lambda x: x[PAYMENT_TYPE] == '2')

# %%
merged_rdd = trips_filtered_rdd.keyBy(lambda x: x[PULOCATIONID]).join(taxi_zones_rdd.keyBy(lambda x: x[0])) \
    .map(lambda x: (x[1][0][0], x[1][0][1], x[1][0][2], x[1][0][3], x[1][0][4], x[1][0][5], x[1][0][6], x[1][1][1]))

# %%
# agregacja (month, borough) -> (sum: passenger_count, sum: total_amount, sum: trip_distance, count_trips)
agg_boroughs_rdd = merged_rdd.map(lambda x: ((x[MONTH],x[-1]),(x[PASSENGER_COUNT], x[TRIP_DISTANCE], x[TOTAL_AMOUNT], 1))).reduceByKey(lambda x,y: (x[0]+y[0],\
    x[1]+y[1], x[2]+y[2], x[3]+y[3]))

# %%
filtered_agg_boroughs_rdd = agg_boroughs_rdd.filter(lambda x: x[1][-1] >= 1000)

# %%
from heapq import nlargest
top_boroughs_rdd = filtered_agg_boroughs_rdd.groupBy(lambda x: x[0][0]).flatMap(lambda x: nlargest(3, x[1], key=lambda y: y[-1]))

# %%
# agregacja (month, borough, day) -> (count_trips)
agg_days_rdd = merged_rdd.map(lambda x: ((x[MONTH], x[-1], x[DAY]), 1)).reduceByKey(lambda x,y: x+y)

# %%
top_days_rdd = agg_days_rdd.groupBy(lambda x: (x[0][0], x[0][1])).flatMap(lambda x: nlargest(3, x[1], key=lambda y: y[1])).map(lambda x: (x[0][0], x[0][1], x[0][2], x[1]))

# %%
top_days_collected_rdd = top_days_rdd.groupBy(lambda x: (x[0], x[1])).map(lambda x: (x[0],[(y[2], y[3]) for y in x[1]]))

# %%
final_rdd = top_boroughs_rdd.join(top_days_collected_rdd).map(lambda x: (x[0][0], x[0][1], x[1][0][0], x[1][0][2], x[1][0][1], x[1][1]))

# %%
final_rdd.saveAsPickleFile(rdd_result_dir)

# %% [markdown]
# Poniższy paragraf zapisuje metryki po uruchomieniu Twojego rozwiązania *misji głównej*.
#
# Nie musisz go uruchamiać podczas implementacji rozwiązania.

# %%
# NIE ZMIENIAĆ
after_rdd_metrics = get_current_metrics(spark_ui_address)

# %% [markdown]
# # Część 2 - Spark SQL (DataFrame)
#
# ## Misje poboczne
#
# W ponizszych paragrafach wprowadź swoje rozwiązania *misji pobocznych*, o ile **nie** chcesz, aby oceniana była *misja główna*. W przeciwnym przypadku **KONIECZNIE** pozostaw je **puste**.

# %% [markdown]
# ## Misja główna
#
# Poniższy paragraf zapisuje metryki przed uruchomieniem Twojego rozwiązania *misji głównej*.
#
# Nie musisz go uruchamiać podczas implementacji rozwiązania.

# %%
# NIE ZMIENIAĆ
before_df_metrics = get_current_metrics(spark_ui_address)

# %% [markdown]
# W poniższych paragrafach wprowadź **rozwiązanie** *misji głównej* swojego projektu oparte o *DataFrame API*.
#
# Pamiętaj o wydajności Twojego przetwarzania, *DataFrame API* nie jest w stanie wszystkiego "naprawić".
#
# Nie wprowadzaj w poniższych paragrafach żadnego kodu, w przypadku wykorzystania *misji pobocznych*.

# %%
from pyspark.sql.functions import split, explode, count, col
from pyspark.sql.window import Window
from pyspark.sql.functions import rank, sum, collect_list, struct, row_number
# Wczytanie danych
trips_data = spark.read.text(datasource1_dir)
taxi_zones_data = spark.read.text(datasource4_dir)

trips_df = trips_data.select(
    split(trips_data['value'], ',').alias('data')
).select(
    col('data')[1].substr(0, 7).alias('month'),
    col('data')[1].substr(9, 2).alias('day'),
    col('data')[3].cast('int').alias('Passenger_count'),
    col('data')[4].cast('float').alias('Trip_distance'),
    col('data')[7].alias('PULocationID'),
    col('data')[9].alias('Payment_type'),
    col('data')[16].cast('float').alias('Total_amount')
)

taxi_zones_df = taxi_zones_data.select(split(taxi_zones_data['value'], ',').alias('data')
).select(
    col('data')[0].alias('LocationID'),
    col('data')[1].alias('Borough'),
)

taxi_zones_df = taxi_zones_df.exceptAll(taxi_zones_df.limit(1))

# %%
trips_filtered_df = trips_df.filter(col("Payment_type") == '2')

# %%
merged_df = trips_filtered_df.join(taxi_zones_df, col("PULocationID") == col("LocationID"))

# %%
agg_boroughs_df = merged_df.groupBy("month", "Borough").agg(
    sum("Passenger_count").alias("passengers"),
    sum("Total_amount").alias("total_amount"),
    sum("Trip_distance").alias("trip_distance"),
    count("*").alias("count_trips")
).orderBy("month", "Borough")

filtered_agg_boroughs_df = agg_boroughs_df.filter(col("count_trips") >= 1000)

# %%
windowSpec = Window.partitionBy("month").orderBy(col("passengers").desc())
ranked_boroughs_df = filtered_agg_boroughs_df.withColumn("rank", rank().over(windowSpec))
top_boroughs_df = ranked_boroughs_df.filter(col("rank") <= 3).orderBy(col("month").desc())

# %%
agg_days_df = merged_df.groupBy("month", "Borough", "day").agg(
    count("*").alias("count_trips")
).orderBy("month", "Borough", col("count_trips").desc())

# %%
windowSpec = Window.partitionBy("month", "Borough").orderBy(col("count_trips").desc())
ranked_data_df = agg_days_df.withColumn("rank", rank().over(windowSpec))
top_days_df = ranked_data_df.filter(col("rank") <= 3).orderBy(col("month").desc(), "Borough", col("count_trips").desc())

# %%
top_days_collected_df = top_days_df.groupBy("month", "Borough").agg(collect_list(struct("day", "count_trips")).alias("top_days"))

# %%
final_df = top_boroughs_df.join(top_days_collected_df, on=["month", "Borough"], how="left").select("month", "Borough", "passengers", "total_amount", "trip_distance", "top_days")

# %%
final_df.write.mode("overwrite").saveAsTable(df_result_table)
# Out:
# 24/01/15 20:00:18 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.

# %% [markdown]
# Poniższy paragraf zapisuje metryki po uruchomieniu Twojego rozwiązania *misji głównej*.
#
# Nie musisz go uruchamiać podczas implementacji rozwiązania.

# %%
# NIE ZMIENIAĆ
after_df_metrics = get_current_metrics(spark_ui_address)

# %% [markdown]
# # Część 3 - Pandas API on Spark
#
# Ta część to wyzwanie. W szczególności dla osób, które nie programują na co dzień w Pythonie, lub które nie nie korzystały do tej pory z Pandas API.
#
# Powodzenia!
#
# ## Misje poboczne
#
# W ponizszych paragrafach wprowadź swoje rozwiązania *misji pobocznych*, o ile **nie** chcesz, aby oceniana była *misja główna*. W przeciwnym przypadku **KONIECZNIE** pozostaw je **puste**.

# %% [markdown]
# ## Misja główna
#
# Poniższy paragraf zapisuje metryki przed uruchomieniem Twojego rozwiązania *misji głównej*.
#
# Nie musisz go uruchamiać podczas implementacji rozwiązania.

# %%
#NIE ZMIENIAĆ
before_ps_metrics = get_current_metrics(spark_ui_address)

# %% [markdown]
# W poniższych paragrafach wprowadź **rozwiązanie** swojego projektu oparte o *Pandas API on Spark*.
#
# Pamiętaj o wydajności Twojego przetwarzania, *Pandas API on Spark* nie jest w stanie wszystkiego "naprawić".
#
# Nie wprowadzaj w poniższych paragrafach żadnego kodu, w przypadku wykorzystania *misji pobocznych*.

# %%
import pyspark.pandas as ps

trips_ps = ps.read_csv(datasource1_dir, header=None)
trips_ps.columns = ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'Passenger_count', 'Trip_distance', 'RateCodeID', 'Store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'Payment_type', 'Fare_amount', 'Extra', 'MTA_tax', 'Tip_amount', 'Tolls_amount', 'Improvement_surcharge', 'Total_amount']
trips_ps['month'] = trips_ps['tpep_pickup_datetime'].dt.strftime('%Y-%m')
trips_ps['day'] = trips_ps['tpep_pickup_datetime'].dt.day
trips_ps = trips_ps.drop(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'RateCodeID', 'Store_and_fwd_flag', 'DOLocationID', 'Fare_amount', 'Extra', 'MTA_tax', 'Tip_amount', 'Tolls_amount', 'Improvement_surcharge'], axis=1)
taxi_zones_ps = ps.read_csv(datasource4_dir)
taxi_zones_ps = taxi_zones_ps.drop(['Zone', 'service_zone'], axis=1)
# Out:
# /usr/lib/spark/python/pyspark/pandas/__init__.py:49: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
# /usr/lib/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `read_csv`, the default index is attached which can cause additional overhead.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
trips_filtered_ps = trips_ps[trips_ps["Payment_type"] == '2']

# %%
merged_ps = trips_filtered_ps.merge(taxi_zones_ps, left_on="PULocationID", right_on="LocationID")

# %%
agg_boroughs_ps = merged_ps.groupby(["month", "Borough"]).agg(
    passengers=("Passenger_count", "sum"),
    total_amount=("Total_amount", "sum"),
    trip_distance=("Trip_distance", "sum"),
    count_trips=("month", "count")
).reset_index()

# %%
filtered_agg_boroughs_ps = agg_boroughs_ps[agg_boroughs_ps["count_trips"] >= 1000]

# %%
top_boroughs_ps = filtered_agg_boroughs_ps.sort_values(by=['month', 'count_trips'], ascending=[True, False]).groupby('month').head(3).reset_index()

# %%
agg_days_ps = merged_ps.groupby(["month", "Borough", "day"]).agg(
    count_trips=("month", "count")
).reset_index()

# %%
top_days_ps = agg_days_ps.sort_values(by=["month", "Borough", "count_trips"], ascending=[True, True, False]).groupby(["month", "Borough"]).head(3).reset_index()

# %%
top_days_collected_ps = top_days_ps.groupby(["month", "Borough"])[['day', 'count_trips']].apply(lambda x: x.values.tolist()).reset_index(name='top_days')
# Out:
# /usr/lib/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: If the type hints is not specified for `grouby.apply`, it is expensive to infer the data type internally.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
final_ps = top_boroughs_ps.merge(top_days_collected_ps, on=['month', 'Borough'])[['month', 'Borough', 'passengers', 'total_amount', 'trip_distance', 'top_days']]

# %%
final_pandas = final_ps.head(50).to_pandas()
# Out:
# /usr/lib/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
final_pandas.to_json(ps_result_file, orient='index')

# %% [markdown]
# Poniższy paragraf zapisuje metryki po uruchomieniu Twojego rozwiązania *misji głównej*.
#
# Nie musisz go uruchamiać podczas implementacji rozwiązania.

# %%
#NIE ZMIENIAĆ
after_ps_metrics = get_current_metrics(spark_ui_address)

# %% [markdown]
# # Analiza wyników i wydajności *misji głównych*

# %% [markdown]
# ## Część 1 - Spark Core (RDD)

# %%
# Wczytanie wyników z pliku pickle
word_counts = sc.pickleFile(rdd_result_dir)

# Wyświetlenie 50 pierwszych elementów
result_sample = word_counts.take(50)
for item in result_sample:
    print(item)
# Out:
# [Stage 107:=================================================>     (71 + 4) / 79]
# ('2018-11', 'Queens', 251199, 5314633.170000963, 1501460.920000022, [('16', 6653), ('27', 5813), ('01', 5718)])
# ('2018-12', 'Manhattan', 3748256, 27917296.410030242, 4843509.109999998, [('01', 87599), ('08', 85825), ('15', 84043)])
# ('2018-12', 'Queens', 264815, 5389044.160000935, 1525387.2300000123, [('27', 6310), ('21', 6108), ('28', 5987)])
# ('2018-11', 'Unknown', 64540, 625450.1799998876, 105209.79999999944, [('10', 1923), ('23', 1859), ('14', 1710)])
# ('2018-12', 'Unknown', 75779, 697061.930000166, 118279.03999999902, [('08', 2279), ('19', 2030), ('18', 1966)])
# ('2018-11', 'Manhattan', 3459143, 26047331.750026345, 4469622.090000004, [('10', 87158), ('03', 85184), ('17', 84468)])

# %%
subtract_metrics(after_rdd_metrics, before_rdd_metrics)
# Out:
# {
#   "numTasks": 1021,
#   "numActiveTasks": 0,
#   "numCompleteTasks": 1021,
#   "numFailedTasks": 0,
#   "numKilledTasks": 0,
#   "numCompletedIndices": 1021,
#   "executorDeserializeTime": 10009,
#   "executorDeserializeCpuTime": 5842497034,
#   "executorRunTime": 576732,
#   "executorCpuTime": 46139241917,
#   "resultSize": 1931229,
#   "jvmGcTime": 4178,
#   "resultSerializationTime": 43,
#   "memoryBytesSpilled": 0,
#   "diskBytesSpilled": 0,
#   "peakExecutionMemory": 1952841264,
#   "inputBytes": 1424678733,
#   "inputRecords": 16318798,
#   "outputBytes": 960,
#   "outputRecords": 6,
#   "shuffleRemoteBlocksFetched": 9689,
#   "shuffleLocalBlocksFetched": 13946,
#   "shuffleFetchWaitTime": 149,
#   "shuffleRemoteBytesRead": 69896723,
#   "shuffleRemoteBytesReadToDisk": 0,
#   "shuffleLocalBytesRead": 70342853,
#   "shuffleReadBytes": 140239576,
#   "shuffleReadRecords": 23635,
#   "shuffleWriteBytes": 70470227,
#   "shuffleWriteTime": 4812915279,
#   "shuffleWriteRecords": 15071
# }

# %% [markdown]
# ## Część 2 - Spark SQL (DataFrame)

# %%
df = spark.table(df_result_table)

# Wyświetlenie 50 pierwszych rekordów
df.show(50, truncate=False)
# Out:
# +-------+-----------+----------+--------------------+------------------+---------------------------------------+
# |month  |Borough    |passengers|total_amount        |trip_distance     |top_days                               |
# +-------+-----------+----------+--------------------+------------------+---------------------------------------+
# |2018-11|"Queens"   |251199    |5314633.200125992   |1501460.9201596621|[{16, 6653}, {27, 5813}, {01, 5718}]   |
# |2018-11|"Unknown"  |64540     |625450.1823387146   |105209.80002824217|[{10, 1923}, {23, 1859}, {14, 1710}]   |
# |2018-12|"Queens"   |264815    |5389044.19103837    |1525387.2301812489|[{27, 6310}, {21, 6108}, {28, 5987}]   |
# |2018-12|"Manhattan"|3748256   |2.7917296492852896E7|4843509.109785054 |[{01, 87599}, {08, 85825}, {15, 84043}]|
# |2018-11|"Manhattan"|3459143   |2.604733185194066E7 |4469622.089800246 |[{10, 87158}, {03, 85184}, {17, 84468}]|
# |2018-12|"Unknown"  |75779     |697061.9320377801   |118279.04001246765|[{08, 2279}, {19, 2030}, {18, 1966}]   |
# +-------+-----------+----------+--------------------+------------------+---------------------------------------+

# %%
subtract_metrics(after_df_metrics, before_df_metrics)
# Out:
# {
#   "numTasks": 252,
#   "numActiveTasks": 0,
#   "numCompleteTasks": 49,
#   "numFailedTasks": 0,
#   "numKilledTasks": 0,
#   "numCompletedIndices": 49,
#   "executorDeserializeTime": 6050,
#   "executorDeserializeCpuTime": 3299905194,
#   "executorRunTime": 269294,
#   "executorCpuTime": 171990815292,
#   "resultSize": 376990,
#   "jvmGcTime": 4626,
#   "resultSerializationTime": 10,
#   "memoryBytesSpilled": 0,
#   "diskBytesSpilled": 0,
#   "peakExecutionMemory": 2964161856,
#   "inputBytes": 2849332822,
#   "inputRecords": 32637323,
#   "outputBytes": 2715,
#   "outputRecords": 6,
#   "shuffleRemoteBlocksFetched": 31,
#   "shuffleLocalBlocksFetched": 43,
#   "shuffleFetchWaitTime": 0,
#   "shuffleRemoteBytesRead": 372887,
#   "shuffleRemoteBytesReadToDisk": 0,
#   "shuffleLocalBytesRead": 462430,
#   "shuffleReadBytes": 835317,
#   "shuffleReadRecords": 12582,
#   "shuffleWriteBytes": 453946,
#   "shuffleWriteTime": 745118302,
#   "shuffleWriteRecords": 6848
# }

# %% [markdown]
# ## Część 3 - Pandas API on Spark

# %%
import json

# Odczytaj zawartość pliku JSON
with open(ps_result_file, 'r') as file:
    json_content = json.load(file)

# Wyświetl zawartość
print(json.dumps(json_content, indent=2))
# Out:
# {
#   "0": {
#     "month": "2018-12",
#     "Borough": "Unknown",
#     "passengers": 75779,
#     "total_amount": 697061.930000029,
#     "trip_distance": 118279.0400000001,
#     "top_days": [
#       [
#         8,
#         2279
#       ],
#       [
#         19,
#         2030
#       ],
#       [
#         18,
#         1966
#       ]
#     ]
#   },
#   "1": {
#     "month": "2018-12",
#     "Borough": "Queens",
#     "passengers": 264815,
#     "total_amount": 5389044.159999197,
#     "trip_distance": 1525387.230000001,
#     "top_days": [
#       [
#         27,
#         6310
#       ],
#       [
#         21,
#         6108
#       ],
#       [
#         28,
#         5987
#       ]
#     ]
#   },
#   "2": {
#     "month": "2018-11",
#     "Borough": "Unknown",
#     "passengers": 64540,
#     "total_amount": 625450.1800000141,
#     "trip_distance": 105209.8000000001,
#     "top_days": [
#       [
#         10,
#         1923
#       ],
#       [
#         23,
#         1859
#       ],
#       [
#         14,
#         1710
#       ]
#     ]
#   },
#   "3": {
#     "month": "2018-12",
#     "Borough": "Manhattan",
#     "passengers": 3748256,
#     "total_amount": 27917296.410068545,
#     "trip_distance": 4843509.109999993,
#     "top_days": [
#       [
#         1,
#         87599
#       ],
#       [
#         8,
#         85825
#       ],
#       [
#         15,
#         84043
#       ]
#     ]
#   },
#   "4": {
#     "month": "2018-11",
#     "Borough": "Manhattan",
#     "passengers": 3459143,
#     "total_amount": 26047331.750064205,
#     "trip_distance": 4469622.089999992,
#     "top_days": [
#       [
#         10,
#         87158
#       ],
#       [
#         3,
#         85184
#       ],
#       [
#         17,
#         84468
#       ]
#     ]
#   },
#   "5": {
#     "month": "2018-11",
#     "Borough": "Queens",
#     "passengers": 251199,
#     "total_amount": 5314633.169999224,
#     "trip_distance": 1501460.9200000002,
#     "top_days": [
#       [
#         16,
#         6653
#       ],
#       [
#         27,
#         5813
#       ],
#       [
#         1,
#         5718
#       ]
#     ]
#   }
# }

# %%
subtract_metrics(after_ps_metrics, before_ps_metrics)
# Out:
# {
#   "numTasks": 340,
#   "numActiveTasks": 0,
#   "numCompleteTasks": 210,
#   "numFailedTasks": 0,
#   "numKilledTasks": 0,
#   "numCompletedIndices": 210,
#   "executorDeserializeTime": 8083,
#   "executorDeserializeCpuTime": 3228966010,
#   "executorRunTime": 713604,
#   "executorCpuTime": 381093868793,
#   "resultSize": 539048,
#   "jvmGcTime": 27052,
#   "resultSerializationTime": 22,
#   "memoryBytesSpilled": 0,
#   "diskBytesSpilled": 0,
#   "peakExecutionMemory": 613558656,
#   "inputBytes": 9103394391,
#   "inputRecords": 98278488,
#   "outputBytes": 0,
#   "outputRecords": 0,
#   "shuffleRemoteBlocksFetched": 32,
#   "shuffleLocalBlocksFetched": 36,
#   "shuffleFetchWaitTime": 1,
#   "shuffleRemoteBytesRead": 341705,
#   "shuffleRemoteBytesReadToDisk": 0,
#   "shuffleLocalBytesRead": 379571,
#   "shuffleReadBytes": 721276,
#   "shuffleReadRecords": 11520,
#   "shuffleWriteBytes": 381862,
#   "shuffleWriteTime": 799481313,
#   "shuffleWriteRecords": 6234
# }
